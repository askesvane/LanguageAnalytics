# %% [markdown]
# ## LDA machine learning assignment

# %% [markdown]
# Import packages

# %%
# standard library
import sys,os
sys.path.append(os.path.join(".."))
from pprint import pprint

# data and nlp
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_sm", disable=["ner"])

# visualisation
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
import seaborn as sns
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 20,10


# LDA tools
import gensim
import gensim.corpora as corpora
from gensim.models import CoherenceModel
import nltk

# Stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')

import lda_utils
from sklearn.decomposition import PCA

# warnings
import logging, warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
# Out:
# [nltk_data] Downloading package stopwords to /home/cds-
# [nltk_data]     au613522/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Import data

# %%
# Import data from filepath 
filename = os.path.join("data", "philosophy_data.csv")
DATA = pd.read_csv(filename)
DATA[:1]
# Out:
#                     title author school  \
# 0  Plato - Complete Works  Plato  plato
#
#                                       sentence_spacy  \
# 0   What's new, Socrates, to make you leave your ...
#
#                                         sentence_str  \
# 0   What's new, Socrates, to make you leave your ...
#
#    original_publication_date  corpus_edition_date  sentence_length  \
# 0                       -350                 1997              125
#
#                                     sentence_lowered  \
# 0   what's new, socrates, to make you leave your ...
#
#                                        tokenized_txt  \
# 0  ['what', 'new', 'socrates', 'to', 'make', 'you...
#
#                                       lemmatized_str
# 0     what be new , Socrates , to make -PRON- lea...

# %%
# Create a subset and select relevant columns in the data
DATA = DATA.iloc[:,[0,1,2,5,8]].sample(50000)
DATA.head()
# Out:
#                              title       author       school  \
# 134201  The Problems Of Philosophy      Russell     analytic
# 129818      The Search After Truth  Malebranche  rationalism
# 339109      Thus Spake Zarathustra    Nietzsche    nietzsche
# 29157       Plato - Complete Works        Plato        plato
# 163595                Quintessence        Quine     analytic
#
#         original_publication_date  \
# 134201                       1912
# 129818                       1674
# 339109                       1887
# 29157                        -350
# 163595                       1950
#
#                                          sentence_lowered
# 134201  if any one asks: 'why should i accept the resu...
# 129818  thus, the rays that leave each visible point o...
# 339109  but zarathustra kept silent for two days, and ...
# 29157            what happens in the latter case is this.
# 163595  conversely, through our vari ables of quantifi...

# %%
"""
Each document has several entries as a line per sentences appears in the data. 
I comprise all text for each document in the same cell reducing the number of rows
in DATA to the number of documents.
"""

gathered_text = list(DATA.groupby(['title'])['sentence_lowered'].apply(lambda x: ' '.join(x)).reset_index()["sentence_lowered"])

# Only keep 1 row per document.
DATA = DATA.drop_duplicates(subset = ["title"])

# Add the new text column
DATA["text"] = gathered_text

# Drop sentence_lower column since it only contains one sentence and we now have the text column
DATA = DATA.drop("sentence_lowered", axis = 1)

DATA[:3]
# Out:
#                              title       author       school  \
# 134201  The Problems Of Philosophy      Russell     analytic
# 129818      The Search After Truth  Malebranche  rationalism
# 339109      Thus Spake Zarathustra    Nietzsche    nietzsche
#
#         original_publication_date  \
# 134201                       1912
# 129818                       1674
# 339109                       1887
#
#                                                      text
# 134201  we are well aware of the large scale on which ...
# 129818  then, it will be objected that by the foregoin...
# 339109  the examination of the impression bestows a cl...

# %%
# convert column with years to numeric
DATA["original_publication_date"] = pd.to_numeric(DATA["original_publication_date"])

# %%
# Building the bigram and trigram models
bigram = gensim.models.Phrases(DATA["text"], min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[DATA["text"]], min_count = 1, threshold=100)
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

data_processed = lda_utils.process_words(DATA["text"], nlp, bigram_mod, trigram_mod,
                                         allowed_postags=['NOUN']) # consider: ['NOUN', "ADJ", "VERB", "ADV"]

# %%
data_processed
# Out:
# [['scale',
#   'writing',
#   'opinion',
#   'regard',
#   'difficulty',
#   'claim',
#   'rank',
#   'intuition',
#   'truth',
#   'error',
#   'clearness',
#   'consistency',
#   'logic',
#   'hypothesis',
#   'fact',
#   'attempt',
#   'day',
#   'risk',
#   'crowd',
#   'crowd',
#   'intelligence',
#   'mistake',
#   'demand',
#   'notice',
#   'show',
#   'elasticity',
#   'employment',
#   'notice',
#   'elasticity',
#   'employment',
#   'unity',
#   'liquidity',
#   'resource',
#   'emergency',
#   'difficulty',
#   'depression',
#   'deal',
#   'importance',
#   'instance',
#   'conclusion',
#   'economy',
#   'analogy',
#   'kind',
#   'economy',
#   'income',
#   'individual',
#   'retain',
#   'result',
#   'activity',
#   'output',
#   'activity',
#   'system',
#   'borrowing',
#   'lending',
#   'loan',
#   'security',
#   'type',
#   'risk',
#   'lender',
#   'risk',
#   'fact',
#   'schedule',
#   'efficiency',
#   'fall',
#   'rate',
#   'interest',
#   'increase',
#   'investment',
#   'investment',
#   'increase',
#   'investment',
#   'demand',
#   'income',
#   'term',
#   'product',
#   'income',
#   'term',
#   'wage',
#   'unit',
#   'title',
#   'theory',
#   'unemployment',
#   'misnomer',
#   'moment',
#   'fact',
#   'amount',
#   'loss',
#   'expectation',
#   'depreciation',
#   'equipment',
#   'depreciation',
#   'user',
#   'cost',
#   'cost',
#   'machinery',
#   'trade',
#   'dispense',
#   'rate',
#   'interest',
#   'percent',
#   'division',
#   'liquidity',
#   'preference',
#   'hand',
#   'country',
#   'portion',
#   'repercussion',
#   'action',
#   'country',
#   'activity',
#   'judgment',
#   'case',
#   'investment',
#   'term',
#   'wage',
#   'unit',
#   'increase',
#   'savings',
#   'term',
#   'wage',
#   'unit',
#   'efficiency',
#   'capital',
#   'term',
#   'fund',
#   'investment',
#   'rate',
#   'interest',
#   'term',
#   'fund',
#   'entrepreneur',
#   'preference',
#   'part',
#   'equipment',
#   'user',
#   'cost',
#   'factor',
#   'cost',
#   'unit',
#   'output',
#   'danger',
#   'money',
#   'course',
#   'mind',
#   'extent',
#   'saving',
#   'scale',
#   'investment',
#   'scale',
#   'investment',
#   'rate',
#   'interest',
#   'attempt',
#   'way',
#   'point',
#   'correspond',
#   'employment',
#   'remedy',
#   'cheese',
#   'thing',
#   'factory',
#   'bank',
#   'control',
#   'reason',
#   'increase',
#   'quantity',
#   'money',
#   'effect',
#   'price',
#   'unemployment',
#   'employment',
#   'proportion',
#   'demand',
#   'increase',
#   'quantity',
#   'money',
#   'employment',
#   'thenceforward',
#   'wage',
#   'unit',
#   'price',
#   'proportion',
#   'demand',
#   'element',
#   'economy',
#   'rate',
#   'interest',
#   'generality',
#   'wealth',
#   'owner',
#   'matter',
#   'importance',
#   'definition',
#   'income',
#   'definition',
#   'income',
#   'entrepreneur',
#   'profit',
#   'profit',
#   'consumer',
#   'input',
#   'day',
#   'compete',
#   'speak',
#   'input',
#   'date',
#   'input',
#   'cheapness',
#   'reason',
#   'efficiency',
#   'price',
#   'change',
#   'offset',
#   'interest',
#   'notice',
#   'entrepreneur',
#   'change',
#   'demand',
#   'elasticity',
#   'employment',
#   'response',
#   'increase',
#   'investment',
#   'equilibrium',
#   'value',
#   'stock',
#   'surplus',
#   'capacity',
#   'stage',
#   'production',
#   'potentiality',
#   'liquidity',
#   'function',
#   'efficiency',
#   'capital',
#   'importance',
#   'rate',
#   'interest',
#   'expectation',
#   'future',
#   'influence',
#   'work',
#   'reference',
#   'economic',
#   'writing',
#   'reason',
#   'expression',
#   'theory',
#   'author',
#   'reason',
#   'digression',
#   'level',
#   'abstraction',
#   'book',
#   'rate',
#   'saving',
#   'correspond',
#   'state',
#   'employment',
#   'definition',
#   'saving',
#   'employment',
#   'position',
#   'period',
#   'equilibrium',
#   'part',
#   'employment',
#   'disutility',
#   'labour',
#   'term',
#   'wage',
#   'supply',
#   'labour',
#   'wage',
#   'set',
#   'level',
#   'employment',
#   'intelligence',
#   'defeat',
#   'force',
#   'time',
#   'ignorance',
#   'future',
#   'gun',
#   'chapter',
#   'definition',
#   'employment',
#   'term',
#   'school',
#   'theory',
#   'rate',
#   'interest',
#   'volume',
#   'proportion',
#   'item',
#   'investment',
#   'provision',
#   'entrepreneur',
#   'respect',
#   'capital',
#   'equipment',
#   'repair',
#   'renewal',
#   'time',
#   'date',
#   'provision',
#   'result',
#   'income',
#   'level',
#   'correspond',
#   'aggregate',
#   'investment',
#   'situation',
#   'enquiry',
#   'money',
#   'want',
#   'rate',
#   'investment',
#   'point',
#   'class',
#   'capital',
#   'asset',
#   'efficiency',
#   'rate',
#   'interest',
#   'statement',
#   'example',
#   'capital',
#   'formation',
#   'period',
#   'production',
#   'advance',
#   'extent',
#   'digression',
#   'case',
#   'sense',
#   'way',
#   'business',
#   'decision',
#   'sequence',
#   'event',
#   'spite',
#   'indeterminacy',
#   'concept',
#   'equipment',
#   'question',
#   'user',
#   'cost',
#   'proportion',
#   'user',
#   'equipment',
#   'work',
#   'efficiency',
#   'circumstance',
#   'allowance',
#   'cost',
#   'basis',
#   'value',
#   'expectation',
#   'accounting',
#   'interval',
#   'usage',
#   'purchase',
#   'asset',
#   'corporation',
#   'calculation',
#   'animal',
#   'spirit',
#   'loss',
#   'pioneer',
#   'experience',
#   'man',
#   'expectation',
#   'death',
#   'money',
#   'rate',
#   'interest',
#   'reader',
#   'percentage',
#   'sum',
#   'money',
#   'delivery',
#   'year',
#   'spot',
#   'cash',
#   'price',
#   'sum',
#   'delivery',
#   'news',
#   'individual',
#   'lnterest',
#   'room',
#   'activity',
#   'bond',
#   'market',
#   'response',
#   'industry',
#   'change',
#   'employment',
#   'demand',
#   'curve',
#   'industry',
#   'conjunction',
#   'supply',
#   'curve',
#   'family',
#   'curve',
#   'assumption',
#   'employment',
#   'increase',
#   'quantity',
#   'money',
#   'uncertainty',
#   'liquidity',
#   'preference',
#   'motive',
#   'opinion',
#   'future',
#   'rate',
#   'interest',
#   'change',
#   'rate',
#   'movement',
#   'cash',
#   'book',
#   'hand',
#   'force',
#   'change',
#   'output',
#   'employment',
#   'whole',
#   'money',
#   'scheme',
#   'detail',
#   'aggregate',
#   'saving',
#   'difference',
#   'loss',
#   'courage',
#   'skill',
#   'fortune',
#   'sense',
#   'value',
#   'one',
#   'case',
#   'employment',
#   'function',
#   'task',
#   'function',
#   'industry',
#   'change',
#   'change',
#   'account',
#   'effect',
#   'change',
#   'cost',
#   'rate',
#   'interest',
#   'retard',
#   'investment',
#   'income',
#   'amount',
#   'consumption',
#   'income',
#   'definition',
#   'income',
#   'man',
#   'scale',
#   'consumption',
#   'amount',
#   'investment',
#   'receipt',
#   'entrepreneur',
#   'induce',
#   'offer',
#   'amount',
#   'employment',
#   'course',
#   'case',
#   'rate',
#   'time',
#   'ratio',
#   'exchange',
#   'good',
#   'good',
#   'complexity',
#   'course',
#   'event',
#   'theory',
#   'approach',
#   'problem',
#   'condition',
#   'existence',
#   'liquidity',
#   'preference',
#   'money',
#   'wealth',
#   'circumstance',
#   'allowance',
#   'factor',
#   'affair',
#   'lottery',
#   'result',
#   'ability',
#   'character',
#   'manager',
#   'way',
#   'proceed',
#   'production',
#   'type',
#   'capital',
#   'build',
#   'schedule',
#   'investment',
#   'increase',
#   'period',
#   'order',
#   'efficiency',
#   'fall',
#   'figure',
#   'boom',
#   'end',
#   'slump',
#   'combination',
#   'rate',
#   'interest',
#   'state',
#   'expectation',
#   'employment',
#   'state',
#   'prevent',
#   'rate',
#   'interest',
#   'fact',
#   'deterrent',
#   'state',
#   'account',
#   'treatise',
#   'school',
#   'spectacle',
#   'investment',
#   'market',
#   'conclusion',
#   'purchase',
#   'investment',
#   'marriage',
#   'reason',
#   'death',
#   'grave',
#   'cause',
#   'remedy',
#   'evil',
#   'problem',
#   'theme',
#   'tendency',
#   'outcome',
#   'investment',
#   'market',
#   'yield',
#   'capital',
#   'rate',
#   'interest',
#   'schedule',
#   'efficiency',
#   'capital',
#   'investment',
#   'disproportion',
#   'change',
#   'change',
#   'yield',
#   'capital',
#   'rate',
#   'interest',
#   'change',
#   'rate',
#   'investment',
#   'money',
#   'rate',
#   'interest',
#   'rate',
#   'owner',
#   'wealth',
#   'desire',
#   'capital',
#   'asset',
#   'yield',
#   'consumption',
#   'level',
#   'income',
#   'employment',
#   'change',
#   'propensity',
#   'return',
#   'margin',
#   'number',
#   'labour',
#   'unit',
#   'capital',
#   'equipment',
#   'income',
#   'term',
#   'wage',
#   'unit',
#   'proportion',
#   'amount',
#   'employment',
#   'turn',
#   'increase',
#   'proportion',
#   'amount',
#   'income',
#   'term',
#   'product',
#   'investment',
#   'margin',
#   'call',
#   'increase',
#   'amount',
#   'period',
#   'output',
#   'value',
#   'consumption',
#   'case',
#   'term',
#   'expectation',
#   'expectation',
#   'rule',
#   'cause',
#   'abandonment',
#   'work',
#   'process',
#   'light',
#   'expectation',
#   'mistake',
#   'time',
#   'preparation',
#   'employment',
#   'reach',
#   'level',
#   'state',
#   'expectation',
#   'way',
#   'significance',
#   'theory',
#   'chapter',
#   'render',
#   'indicator',
#   'benefit',
#   'employment',
#   'expansion',
#   'capital',
#   'lapse',
#   'time',
#   'attendant',
#   'circumstance',
#   'case',
#   'individual',
#   'process',
#   'book',
#   'theory',
#   'employment',
#   'interest',
#   'money',
#   'feature',
#   'attention',
#   'treatment',
#   'money',
#   'price',
#   'reader',
#   'matter',
#   'significance',
#   'importance',
#   'levy',
#   'thing',
#   'stream',
#   'capital',
#   'rate',
#   'interest',
#   'loan',
#   'content',
#   'century',
#   'theory',
#   'economic',
#   'predominant',
#   'case',
#   'factor',
#   'increase',
#   'investment',
#   'kind',
#   'result',
#   'convention',
#   'organisation',
#   'country',
#   'income',
#   'pressure',
#   'need',
#   'diminishe',
#   'margin',
#   'life',
#   'income',
#   'diminishe',
#   'measure',
#   'justification',
#   'activity',
#   'capitalist',
#   'support',
#   'force',
#   'concept',
#   'analysis',
#   'revaluation',
#   'investment',
#   'practice',
#   'calculating',
#   'rate',
#   'interest',
#   'decision',
#   'entrepreneur',
#   'scale',
#   'output',
#   'scale',
#   'day',
#   'reference',
#   'stock',
#   'good',
#   'rate',
#   'interest',
#   'interaction',
#   'schedule',
#   'efficiency',
#   'capital',
#   'save',
#   'rate',
#   'interest',
#   'money',
#   'part',
#   'limit',
#   'level',
#   'employment',
#   'efficiency',
#   'capital',
#   'asset',
#   'century',
#   'growth',
#   'population',
#   'invention',
#   'land',
#   'state',
#   'confidence',
#   'frequency',
#   'war',
#   'average',
#   'decade',
#   'conjunction',
#   'propensity',
#   'schedule',
#   'efficiency',
#   'capital',
#   'level',
#   'employment',
#   'rate',
#   'interest',
#   'wealth',
#   'owner',
#   'investment',
#   'boom',
#   'remedy',
#   'rate',
#   'interest',
#   'investment',
#   'propensity',
#   'step',
#   'redistributing',
#   'income',
#   'propensity',
#   'fact',
#   'assumption',
#   'state',
#   'day',
#   'theory',
#   'element',
#   'unreality',
#   'quantity',
#   'money',
#   'price',
#   'bond',
#   'expectation',
#   'bull',
#   'influence',
#   'bond',
#   'cash',
#   'society',
#   'dinner',
#   'phase',
#   'dinner',
#   'efficiency',
#   'capital',
#   'investment',
#   'consumption',
#   'suitability',
#   'doctrine',
#   'environment',
#   'correspond',
#   'point',
#   'profit',
#   'output',
#   'trading',
#   'loss',
#   'change',
#   'rate',
#   'consumption',
#   'direction',
#   'amount',
#   'change',
#   'rate',
#   'income',
#   'length',
#   'professor',
#   'pigou',
#   'theory',
#   'unemployment',
#   'criticism',
#   'economist',
#   'school',
#   'attempt',
#   'theory',
#   'unemployment',
#   'money',
#   'device',
#   'future',
#   'effect',
#   'expectation',
#   'activity',
#   'term',
#   'fund',
#   'power',
#   'consumer',
#   'demand',
#   'expenditure',
#   'replacement',
#   'provision',
#   'demand',
#   'increase',
#   'year',
#   'replacement',
#   'statement',
#   'fact',
#   'capital',
#   'existence',
#   'propensity',
#   'response',
#   'demand',
#   'consumption',
#   'history',
#   'method',
#   'efficacy',
#   'country',
#   'advantage',
#   'variance',
#   'neighbour',
#   'gold',
#   'standard',
#   'man',
#   'percent',
#   'income',
#   'amount',
#   'cash',
#   'individual',
#   'satisfy',
#   'transaction',
#   'motive',
#   'satisfy',
#   'approximation',
#   'regard',
#   'set',
#   'cash',
#   'holding',
#   'phrase',
#   'marshall',
#   'efficiency',
#   'factor',
#   'production',
#   'utility',
#   'capital',
#   'day',
#   'publication',
#   'book',
#   'mark',
#   'demand',
#   'function',
#   'quantity',
#   'employment',
#   'proceed',
#   'output',
#   'demand',
#   'point',
#   'demand',
#   'function',
#   'conjunction',
#   'condition',
#   'supply',
#   'level',
#   'employment',
#   'profit',
#   'part',
#   'source',
#   'movement',
#   'strength',
#   'interest',
#   'other',
#   'policy',
#   'assumption',
#   'fact',
#   'circumstance',
#   'change',
#   'change',
#   'factor',
#   'transaction',
#   'motive',
#   'cash',
#   'transaction',
#   'business',
#   'exchange',
#   'equipment',
#   'user',
#   'cost',
#   'rate',
#   'interest',
#   'current',
#   'cost',
#   'period',
#   'time',
#   'redundancy',
#   'wastage',
#   'reason',
#   'combination',
#   'force',
#   'economy',
#   'type',
#   'money',
#   'rate',
#   'interest',
#   'decline',
#   'reaction',
#   'wage',
#   'unit',
#   'efficiency',
#   'asset',
#   'term',
#   'money',
#   'difference',
#   'money',
#   'rate',
#   'interest',
#   'level',
#   'interest',
#   'conviction',
#   'course',
#   'society',
#   'fluctuation',
#   'kind',
#   'reason',
#   'reference',
#   'professor',
#   'work',
#   'characteristic',
#   'thought',
#   'period',
#   'century',
#   'time',
#   'reader',
#   'term',
#   'economist',
#   'labour',
#   'cut',
#   'moneywage',
#   'admit',
#   'condition',
#   'integrity',
#   'force',
#   'refusal',
#   'trouble',
#   'conjunction',
#   'income',
#   'figure',
#   'figure',
#   'investment',
#   'multiplier',
#   'business',
#   'man',
#   'fact',
#   'course',
#   'money',
#   'wage',
#   'supposition',
#   'professor',
#   'pigou',
#   'unemployment',
#   'member',
#   'school',
#   'tendency',
#   ...],
#  ['foregoing',
#   'principle',
#   'scheme',
#   'idea',
#   'place',
#   'thing',
#   'body',
#   'substance',
#   'sense',
#   'principle',
#   'difference',
#   'thing',
#   'idea',
#   'reality',
#   'chimera',
#   'soever',
#   'attempt',
#   'man',
#   'design',
#   'hope',
#   'consideration',
#   'view',
#   'draw',
#   'object',
#   'nearer',
#   'survey',
#   'discern',
#   'eye',
#   'frame',
#   'idea',
#   'happiness',
#   'pleasure',
#   'goodness',
#   'example',
#   'skill',
#   'form',
#   'idea',
#   'none',
#   'rectangle',
#   'wind',
#   'treasure',
#   'quality',
#   'thing',
#   'denomination',
#   'number',
#   'mind',
#   'respect',
#   'place',
#   'part',
#   'space',
#   'body',
#   'space',
#   'place',
#   'consideration',
#   'motion',
#   'space',
#   'sense',
#   'body',
#   'mind',
#   'principle',
#   'object',
#   'sense',
#   'idea',
#   'resemblance',
#   'mind',
#   'idea',
#   'quality',
#   'pattern',
#   'image',
#   'thing',
#   'mind',
#   'substance',
#   'call',
#   'content',
#   'issue',
#   'substance',
#   'idea',
#   'idea',
#   'mind',
#   'perceiving',
#   'supposition',
#   'existence',
#   'imagination',
#   'notion',
#   'task',
#   'tender',
#   'age',
#   'hardness',
#   'taste',
#   'warmth',
#   'figure',
#   'quality',
#   'sort',
#   'victual',
#   'apparel',
#   'mind',
#   'perceive',
#   'word',
#   'line',
#   'scheme',
#   'inch',
#   'part',
#   'signification',
#   'line',
#   'part',
#   'example',
#   'name',
#   'idea',
#   'philosopher',
#   'mind',
#   'spirit',
#   'idea',
#   'mind',
#   'spirit',
#   'resemblance',
#   'spirit',
#   'soul',
#   'sense',
#   'image',
#   'idea',
#   'respect',
#   'spirit',
#   'heat',
#   'idea',
#   'manner',
#   'notion',
#   'relation',
#   'thing',
#   'idea',
#   'relation',
#   'idea',
#   'thing',
#   'confess',
#   'motion',
#   'motion',
#   'body',
#   'distance',
#   'position',
#   'regard',
#   'notion',
#   'source',
#   'whence',
#   'paradox',
#   'sense',
#   'mankind',
#   'reluctance',
#   'mind',
#   'occasion',
#   'subtilty',
#   'mathematic',
#   'argue',
#   'existence',
#   'thing',
#   'apprehend',
#   'reflexion',
#   'opinion',
#   'spirit',
#   'manner',
#   'sensation',
#   'heterodox',
#   'scepticism',
#   'nature',
#   'soul',
#   'object',
#   'sense',
#   'tree',
#   'chair',
#   'substance',
#   'extension',
#   'figure',
#   'motion',
#   'monster',
#   'fruit',
#   'rain',
#   'desert',
#   'misery',
#   'life',
#   'argument',
#   'frame',
#   'nature',
#   'spirit',
#   'wisdom',
#   'goodness',
#   'reason',
#   'body',
#   'magnitude',
#   'exhibit',
#   'number',
#   'part',
#   'sense',
#   'number',
#   'part',
#   'doctrine',
#   'obtain',
#   'foundation',
#   'geometry',
#   'man',
#   'science',
#   'height',
#   'building',
#   'air',
#   'word',
#   'sign',
#   'idea',
#   'idea',
#   'creation',
#   'workmanship',
#   'agent',
#   'philosopher',
#   'employ',
#   'thought',
#   'cause',
#   'thing',
#   'confess',
#   'reason',
#   'end',
#   'thing',
#   'wisdom',
#   'way',
#   'philosopher',
#   'thought',
#   'compass',
#   'nature',
#   'similitude',
#   'appearance',
#   'earth',
#   'body',
#   'tendency',
#   'name',
#   'attraction',
#   'method',
#   'providence',
#   'appetite',
#   'creature',
#   'mean',
#   'use',
#   'fail',
#   'satisfy',
#   'propriety',
#   'truth',
#   'expression',
#   'style',
#   'talk',
#   'doubt',
#   'production',
#   'idea',
#   'sensation',
#   'mind',
#   'reason',
#   'matter',
#   'corporeal',
#   'word',
#   'contradiction',
#   'part',
#   'call',
#   'extension',
#   'thought',
#   'idea',
#   'mind',
#   'part',
#   'argument',
#   'colour',
#   'taste',
#   'mind',
#   'force',
#   'prove',
#   'thing',
#   'extension',
#   'figure',
#   'motion',
#   'motion',
#   'force',
#   'body',
#   'frame',
#   'position',
#   'organ',
#   'sense',
#   'frame',
#   'idea',
#   'space',
#   'body',
#   'nature',
#   'act',
#   'stock',
#   'argument',
#   'depreciate',
#   'faculty',
#   'mankind',
#   'blindness',
#   'nature',
#   'thing',
#   'idea',
#   'idea',
#   'idea',
#   'agent',
#   'idea',
#   'variety',
#   'part',
#   'idea',
#   'mind',
#   'part',
#   'man',
#   'living',
#   'creature',
#   'idea',
#   'abstract',
#   'man',
#   'beast',
#   'insect',
#   'prospect',
#   'philosopher',
#   'matter',
#   'existence',
#   'object',
#   'mind',
#   'scripture',
#   'manner',
#   'property',
#   'line',
#   'figure',
#   'sign',
#   'thence',
#   'mistake',
#   'nature',
#   'part',
#   'thing',
#   'man',
#   'use',
#   'truth',
#   'object',
#   'sensation',
#   'thing',
#   'edit',
#   'instance',
#   'proposition',
#   'word',
#   'substance',
#   'extension',
#   'figure',
#   'occasion',
#   'instance',
#   'unit',
#   'combination',
#   'idea',
#   'thing',
#   'sense',
#   'substance',
#   'support',
#   'detract',
#   'opinion',
#   'reality',
#   'innovation',
#   'respect',
#   'example',
#   'sight',
#   'object',
#   'compound',
#   'idea',
#   'mind',
#   'constituent',
#   'part',
#   'rest',
#   'frame',
#   'idea',
#   'stone',
#   'swell',
#   'moon',
#   'beseech',
#   'framing',
#   'mind',
#   'idea',
#   'time',
#   'frame',
#   'idea',
#   'act',
#   'thing',
#   'idea',
#   'possibility',
#   'opinion',
#   'argument',
#   'chimera',
#   'illusion',
#   'idea',
#   'purpose',
#   'connexion',
#   'account',
#   'appearance',
#   'quality',
#   'cause',
#   'wit',
#   'figure',
#   'motion',
#   'weight',
#   'quality',
#   'particle',
#   'truth',
#   'agent',
#   'motion',
#   'idea',
#   'appearance',
#   'quality',
#   'thing',
#   'thought',
#   'figure',
#   'motion',
#   'colour',
#   'mind',
#   'mark',
#   'effect',
#   'evince',
#   'spirit',
#   'author',
#   'nature',
#   'foregoing',
#   'principle',
#   'thing',
#   'existence',
#   'reflexion',
#   'spirit',
#   'reason',
#   'time',
#   'part',
#   'abuse',
#   'word',
#   'speech',
#   'idea',
#   'idea',
#   'idea',
#   'name',
#   'mathematician',
#   'man',
#   'error',
#   'doctrine',
#   'idea',
#   'existence',
#   'object',
#   'mind',
#   'colour',
#   'taste',
#   'smell',
#   'figure',
#   'consistence',
#   'thing',
#   'name',
#   'ease',
#   'extension',
#   'figure',
#   'motion',
#   'quality',
#   'quality',
#   'mind',
#   'opposition',
#   'tenet',
#   'part',
#   'country',
#   'negligence',
#   'atheism',
#   'number',
#   'collection',
#   'unit',
#   'thing',
#   'unit',
#   'idea',
#   'number',
#   'name',
#   'figure',
#   'number',
#   'man',
#   'think',
#   'existence',
#   'mind',
#   'wherefore',
#   'conclude',
#   'man',
#   'pain',
#   'industry',
#   'part',
#   'age',
#   'cultivation',
#   'advancement',
#   'science',
#   'part',
#   'darkness',
#   'uncertainty',
#   'dispute',
#   'cogent',
#   'demonstration',
#   'paradox',
#   'understanding',
#   'man',
#   'sense',
#   'idea',
#   'sensation',
#   'reason',
#   'substance',
#   'relation',
#   'figure',
#   'motion',
#   'colour',
#   'trouble',
#   'material',
#   'support',
#   'figure',
#   'motion',
#   'sensible',
#   'quality',
#   'doctrine',
#   'thing',
#   'trace',
#   'master',
#   'labyrinth',
#   'dispute',
#   'nature',
#   'notion',
#   'mind',
#   'archetype',
#   'mind',
#   'object',
#   'sensation',
#   'none',
#   'act',
#   'perceive',
#   'substance',
#   'definition',
#   'negative',
#   'notion',
#   'demonstration',
#   'truth',
#   'copernican',
#   'system',
#   'sun',
#   'sun',
#   'set',
#   'idea',
#   'thing',
#   'deny',
#   'deny',
#   'subsist',
#   'mind',
#   'resemblance',
#   'archetype',
#   'mind',
#   'sensation',
#   'idea',
#   'idea',
#   'idea',
#   'mind',
#   'comprehend',
#   'process',
#   'time',
#   'man',
#   'colour',
#   'rest',
#   'quality',
#   'existence',
#   'mind',
#   'substratum',
#   'material',
#   'substance',
#   'quality',
#   'one',
#   'motion',
#   'mind',
#   'need',
#   'material',
#   'support',
#   'sensation',
#   'thing',
#   'thought',
#   'thing',
#   'sensation',
#   'perception',
#   'mistake',
#   'section',
#   'spirit',
#   'substance',
#   'support',
#   'being',
#   'idea',
#   'substance',
#   'support',
#   'perceive',
#   'idea',
#   'idea',
#   'extent',
#   'variety',
#   'thing',
#   'inference',
#   'notion',
#   'beneficence',
#   'creator',
#   'part',
#   'creation',
#   'subservient',
#   'end',
#   'glory',
#   'comfort',
#   'fellow',
#   'creature',
#   'idea',
#   'mind',
#   'thing',
#   'resemblance',
#   'thing',
#   'mind',
#   'substance',
#   'idea',
#   'endeavour',
#   'view',
#   'thought',
#   'name',
#   'understanding',
#   'time',
#   'sense',
#   'duration',
#   'perseverance',
#   'existence',
#   'thing',
#   'business',
#   'childhood',
#   'objection',
#   'sort',
#   'magnitude',
#   'star',
#   'discovery',
#   'nature',
#   'description',
#   'matter',
#   'light',
#   'enlighten',
#   'cause',
#   'idea',
#   'combination',
#   'idea',
#   'section',
#   'idea',
#   'thing',
#   'manifest',
#   'contradiction',
#   'colour',
#   'figure',
#   'quality',
#   'substance',
#   'idea',
#   'andc',
#   'desire',
#   'existence',
#   'idea',
#   'support',
#   'extension',
#   'quality',
#   'accident',
#   'substance',
#   'substratum',
#   'colour',
#   'man',
#   'sense',
#   'idea',
#   'fiction',
#   'contrivance',
#   'mind',
#   'difficulty',
#   'unit',
#   'divide',
#   'proportion',
#   'thing',
#   'number',
#   'branch',
#   'signification',
#   'word',
#   'meaning',
#   'confine',
#   'thought',
#   'idea',
#   'word',
#   'abundance',
#   'information',
#   'action',
#   'method',
#   'idea',
#   'effect',
#   'discerning',
#   'figure',
#   'texture',
#   'mechanism',
#   'part',
#   'body',
#   'artificial',
#   'property',
#   'thereon',
#   'nature',
#   'thing',
#   'writing',
#   'dispute',
#   'philosopher',
#   'part',
#   'idea',
#   'stature',
#   'stature',
#   'stature',
#   'stature',
#   'time',
#   'sucession',
#   'idea',
#   'mind',
#   'duration',
#   'finite',
#   'spirit',
#   'number',
#   'idea',
#   'action',
#   'spirit',
#   'mind',
#   'truth',
#   'falsity',
#   'existence',
#   'body',
#   'mind',
#   'thing',
#   'sense',
#   'regard',
#   'origin',
#   'mind',
#   'spirit',
#   'perceive',
#   'thought',
#   'reader',
#   'matter',
#   'measure',
#   'design',
#   'notice',
#   'part',
#   'speculation',
#   'error',
#   'difficulty',
#   'part',
#   'knowledge',
#   'objection',
#   'idea',
#   'fault',
#   'faculty',
#   'use',
#   'manner',
#   'word',
#   'mistake',
#   'idea',
#   'name',
#   'character',
#   'idea',
#   'thing',
#   'mind',
#   'knowledge',
#   'nature',
#   'use',
#   'certainty',
#   'man',
#   'body',
#   'body',
#   'object',
#   'sight',
#   'mind',
#   'image',
#   'thing',
#   'plainer',
#   'extension',
#   'idea',
#   'idea',
#   'number',
#   'idea',
#   'word',
#   'spirit',
#   'perceive',
#   'signification',
#   'term',
#   'principle',
#   'difficulty',
#   'roundabout',
#   'method',
#   'thing',
#   'instrument',
#   'machine',
#   'deny',
#   'command',
#   'objection',
#   'force',
#   'hold',
#   'existence',
#   'machine',
#   'mind',
#   'solidity',
#   'figure',
#   'motion',
#   'activity',
#   'efficacy',
#   'effect',
#   'nature',
#   'matter',
#   'corporeal',
#   'pillar',
#   'support',
#   'scepticism',
#   'foundation',
#   'scheme',
#   'irreligion',
#   'man',
#   'speculation',
#   'opinion',
#   'sense',
#   'system',
#   'dependence',
#   'corner',
#   'stone',
#   'fabric',
#   'fall',
#   'ground',
#   'insomuch',
#   'consideration',
#   'absurdity',
#   'atheist',
#   'portion',
#   'supply',
#   'benefit',
#   'mankind',
#   'diversion',
#   'amusement',
#   'order',
#   'notion',
#   'corporeal',
#   'world',
#   'wall',
#   'place',
#   'motion',
#   'manner',
#   'philosopher',
#   'quality',
#   'matter',
#   'mind',
#   'thing',
#   'quality'],
#  ['examination',
#   'impression',
#   'clearness',
#   'idea',
#   'examination',
#   'idea',
#   'clearness',
#   'reasoning',
#   'force',
#   'principle',
#   'support',
#   'misery',
#   'manner',
#   'communication',
#   'passion',
#   'blame',
#   'treachery',
#   'faith',
#   'extent',
#   'commerce',
#   'regard',
#   'promise',
#   'argument',
#   'philosopher',
#   'belief',
#   'mind',
#   'distance',
#   'time',
#   'interruption',
#   'distance',
#   'space',
#   'idea',
#   'passion',
#   'measure',
#   'imagination',
#   'system',
#   'confidence',
#   'experience',
#   'material',
#   'principle',
#   'form',
#   'idea',
#   'individual',
#   'term',
#   'individual',
#   'mean',
#   'habit',
#   'recall',
#   'occasion',
#   'system',
#   'morality',
#   'author',
#   'time',
#   'way',
#   'establishe',
#   'observation',
#   'affair',
#   'copulation',
#   'proposition',
#   'proposition',
#   'sight',
#   'perceive',
#   'quality',
#   'object',
#   'pitch',
#   'object',
#   'denomination',
#   'effect',
#   'hypothesis',
#   'operation',
#   'man',
#   'beast',
#   'hypothesis',
#   'hypothesis',
#   'abide',
#   'trial',
#   'affirm',
#   'one',
#   'endure',
#   'possession',
#   'title',
#   'possession',
#   'law',
#   'call',
#   'ballance',
#   'title',
#   'title',
#   'proceed',
#   'relation',
#   'case',
#   'force',
#   'person',
#   'indifference',
#   'survey',
#   'man',
#   'touch',
#   'case',
#   'contempt',
#   'relation',
#   'effect',
#   'resemblance',
#   'idea',
#   'existence',
#   'relation',
#   'conformity',
#   'experience',
#   'proof',
#   'solidity',
#   'hypothesis',
#   'reason',
#   'fact',
#   'object',
#   'belief',
#   'method',
#   'thinking',
#   'life',
#   'key',
#   'delivery',
#   'corn',
#   'philosopher',
#   'reason',
#   'knowledge',
#   'probability',
#   'evidence',
#   'comparison',
#   'idea',
#   'argument',
#   'effect',
#   'term',
#   'probability',
#   'pride',
#   'humility',
#   'separation',
#   'cause',
#   'passion',
#   'pain',
#   'pleasure',
#   'method',
#   'success',
#   'cause',
#   'love',
#   'property',
#   'object',
#   'reference',
#   'morality',
#   'sentiment',
#   'quality',
#   'form',
#   'notion',
#   'stability',
#   'translation',
#   'sentiment',
#   'influence',
#   'custom',
#   'imagination',
#   'part',
#   'minute',
#   'part',
#   'extension',
#   'conjunction',
#   'appearance',
#   'succession',
#   'perception',
#   'object',
#   'object',
#   'sense',
#   'word',
#   'impression',
#   'mind',
#   'degree',
#   'quantity',
#   'quality',
#   'parallel',
#   'instance',
#   'affection',
#   'object',
#   'source',
#   'relation',
#   'time',
#   'species',
#   'object',
#   'form',
#   'quality',
#   'foundation',
#   'simplicity',
#   'identity',
#   'specie',
#   'explication',
#   'passion',
#   'hinder',
#   'man',
#   'interest',
#   'behaviour',
#   'other',
#   'hinder',
#   'equity',
#   'partiality',
#   'favour',
#   'consequence',
#   'war',
#   'dissention',
#   'servant',
#   'sentiment',
#   'kindness',
#   'marcus',
#   'history',
#   'account',
#   'character',
#   'case',
#   'subject',
#   'principle',
#   'observation',
#   'thing',
#   'world',
#   'wish',
#   'person',
#   'decorum',
#   'character',
#   'manner',
#   'reflexion',
#   'perception',
#   'impression',
#   'idea',
#   'sort',
#   'commerce',
#   'form',
#   'word',
#   'bind',
#   'performance',
#   'action',
#   'truth',
#   'obstacle',
#   'difficulty',
#   'sense',
#   'deformity',
#   'object',
#   'theory',
#   'satisfaction',
#   'head',
#   'insolence',
#   'person',
#   'connexion',
#   'relation',
#   'object',
#   'impression',
#   'memory',
#   'sense',
#   'effect',
#   'inference',
#   'remove',
#   'relation',
#   'removal',
#   'passion',
#   'reason',
#   'man',
#   'possession',
#   'property',
#   'society',
#   'act',
#   'generosity',
#   'relief',
#   'person',
#   'account',
#   'object',
#   'mind',
#   'continuity',
#   'action',
#   'greatness',
#   'proportion',
#   'interruption',
#   'object',
#   'cease',
#   'progress',
#   'thought',
#   'identity',
#   'question',
#   'evade',
#   'difficulty',
#   'definition',
#   'substance',
#   'definition',
#   'definition',
#   'thing',
#   'substance',
#   'accident',
#   'soul',
#   'perception',
#   'language',
#   'word',
#   'relation',
#   'philosophy',
#   'mean',
#   'comparison',
#   'person',
#   'interest',
#   'passion',
#   'pain',
#   'pleasure',
#   'manner',
#   'emotion',
#   'one',
#   'idea',
#   'impression',
#   'discover',
#   'formation',
#   'society',
#   'edifice',
#   'existence',
#   'body',
#   'appearance',
#   'coherence',
#   'order',
#   'account',
#   'opinion',
#   'idea',
#   'term',
#   'term',
#   'conjunction',
#   'relation',
#   'idea',
#   'imagination',
#   'fortune',
#   'effect',
#   'mixture',
#   'combination',
#   'body',
#   'memory',
#   'nature',
#   'judgment',
#   'difference',
#   'judgment',
#   'connexion',
#   'effect',
#   'occasion',
#   'remark',
#   'resemblance',
#   'difference',
#   'enthusiasm',
#   'conviction',
#   'case',
#   'body',
#   'eye',
#   'distance',
#   'distance',
#   'increase',
#   'diminution',
#   'motion',
#   'body',
#   'frenchman',
#   'reason',
#   'conversation',
#   'instance',
#   'prejudice',
#   'dunce',
#   'spite',
#   'sense',
#   'reason',
#   'union',
#   'soul',
#   'body',
#   'question',
#   'substance',
#   'mind',
#   'cause',
#   'question',
#   'idea',
#   'motion',
#   'experience',
#   'circumstance',
#   'idea',
#   'effect',
#   'operation',
#   'matter',
#   'motion',
#   'thought',
#   'perception',
#   'change',
#   'train',
#   'thought',
#   'idea',
#   'reasoning',
#   'term',
#   'case',
#   'idea',
#   'compass',
#   'excite',
#   'habit',
#   'mind',
#   'readiness',
#   'conclusion',
#   'idea',
#   'mile',
#   'league',
#   'distance',
#   'thing',
#   'neighbourhood',
#   'friend',
#   'family',
#   'idea',
#   'influence',
#   'action',
#   'respect',
#   'beast',
#   'suspicion',
#   'mistake',
#   'confirmation',
#   'proof',
#   'system',
#   'idea',
#   'solidity',
#   'order',
#   'inference',
#   'relation',
#   'relation',
#   'method',
#   'argument',
#   'praise',
#   'action',
#   'motive',
#   'action',
#   'sign',
#   'indication',
#   'principle',
#   'temper',
#   'suppose',
#   'person',
#   'metal',
#   'ship',
#   'wood',
#   'suppose',
#   'proprietor',
#   'metal',
#   'wood',
#   'demand',
#   'good',
#   'ship',
#   'survey',
#   'appearance',
#   'use',
#   'distinction',
#   'perception',
#   'limit',
#   'decision',
#   'idea',
#   'impression',
#   'impression',
#   'idea',
#   'object',
#   'impression',
#   'degree',
#   'humility',
#   'case',
#   'passion',
#   'pleasure',
#   'esteem',
#   'love',
#   'distinction',
#   'action',
#   'nature',
#   'capacity',
#   'instance',
#   'sagacity',
#   'preservation',
#   'propagation',
#   'specie',
#   'pride',
#   'humility',
#   'quality',
#   'body',
#   'self',
#   'cause',
#   'experience',
#   'object',
#   'affection',
#   'measure',
#   'multiplicity',
#   'extrinsic',
#   'case',
#   'accession',
#   'bottom',
#   'merit',
#   'attention',
#   'occupation',
#   'prescription',
#   'accession',
#   'succession',
#   'touch',
#   'contact',
#   'messenger',
#   'form',
#   'relation',
#   'case',
#   'tho',
#   'force',
#   'succession',
#   'consent',
#   'parent',
#   'relation',
#   'interest',
#   'mankind',
#   'man',
#   'possession',
#   'dearest',
#   'order',
#   'thinking',
#   'object',
#   'mind',
#   'presence',
#   'object',
#   'vivacity',
#   'number',
#   'effect',
#   'cause',
#   'cause',
#   'effect',
#   'harm',
#   'event',
#   'person',
#   'power',
#   'harming',
#   'exert',
#   'prevent',
#   'uneasiness',
#   'uncertainty',
#   'concern',
#   'interest',
#   'reputation',
#   'action',
#   'concern',
#   'honesty',
#   'place',
#   'matter',
#   'nature',
#   'horse',
#   'dragon',
#   'giant',
#   'case',
#   'thing',
#   'person',
#   'consequence',
#   'perception',
#   'existence',
#   'philosopher',
#   'opinion',
#   'change',
#   'system',
#   'distinguish',
#   'betwixt',
#   'perception',
#   'return',
#   'preserve',
#   'existence',
#   'identity',
#   'conjunction',
#   'object',
#   'idea',
#   'thing',
#   'effect',
#   'thing',
#   'advantage',
#   'materialist',
#   'antagonist',
#   'principle',
#   'truth',
#   'error',
#   'cause',
#   'probability',
#   'assurance',
#   'decision',
#   'perception',
#   'object',
#   'appearance',
#   'sense',
#   'think',
#   'perception',
#   'object',
#   'existence',
#   'vivacity',
#   'conjunction',
#   'present',
#   'impression',
#   'imagination',
#   'action',
#   'poetry',
#   'eloquence',
#   'vanity',
#   'boast',
#   'possession',
#   'descent',
#   'honour',
#   'fortune',
#   'avoid',
#   'offence',
#   'virtue',
#   'use',
#   'word',
#   'vanity',
#   'quality',
#   'relation',
#   'vice',
#   'point',
#   'history',
#   'assurance',
#   'million',
#   'effect',
#   'chain',
#   'argument',
#   'length',
#   'praise',
#   'other',
#   'pleasure',
#   'opinion',
#   'quality',
#   'idea',
#   'represent',
#   'impression',
#   'form',
#   'relation',
#   'object',
#   'thence',
#   'property',
#   'principle',
#   'perception',
#   'existent',
#   'absurdity',
#   'perception',
#   'mind',
#   'breaking',
#   'relation',
#   'mass',
#   'perception',
#   'passion',
#   'soul',
#   'shew',
#   'sense',
#   'side',
#   'order',
#   'thing',
#   'one',
#   'foregoing',
#   'argument',
#   'religion',
#   'hope',
#   'apology',
#   'apprehension',
#   'quality',
#   'individual',
#   'choice',
#   'imagination',
#   'object',
#   'object',
#   'effect',
#   'quality',
#   'obscurity',
#   'uncertainty',
#   'effort',
#   'compleat',
#   'idea',
#   'spirit',
#   'force',
#   'person',
#   'possest',
#   'probability',
#   'examine',
#   'contrariety',
#   'experiment',
#   'principle',
#   'connexion',
#   'fear',
#   'uncertainty',
#   'doubt',
#   'passion',
#   'man',
#   'education',
#   'society',
#   'infinite',
#   'advantage',
#   'affection',
#   'company',
#   'conversation',
#   'disturbance',
#   'society',
#   'good',
#   'looseness',
#   'transition',
#   'person',
#   'remedy',
#   'good',
#   'advantage',
#   'body',
#   'nature',
#   'position',
#   'body',
#   'man',
#   'folly',
#   'prudent',
#   'withhold',
#   'assent',
#   'eloquence',
#   'vivacity',
#   'case',
#   'custom',
#   'experience',
#   'effect',
#   'juster',
#   'idea',
#   'penetration',
#   'proceeding',
#   'reasoning',
#   'step',
#   'chance',
#   'negation',
#   'cause',
#   'indifference',
#   'mind',
#   'negation',
#   'indifference',
#   'cause',
#   'chance',
#   'effect',
#   'combination',
#   'chance',
#   'mind',
#   'manner',
#   'judgment',
#   'opinion',
#   'eloquence',
#   'pride',
#   'humility',
#   'quality',
#   'system',
#   'ethick',
#   'part',
#   'duty',
#   'connexion',
#   'pleasure',
#   'uneasiness',
#   'sight',
#   'hypothesis',
#   'relation',
#   'impression',
#   'idea',
#   'case',
#   'excite',
#   'pride',
#   'object',
#   'viz',
#   'system',
#   'principle',
#   'mind',
#   'reason',
#   'destruction',
#   'world',
#   'finger',
#   'answer',
#   'argument',
#   'mind',
#   'idea',
#   'capacity',
#   'order',
#   'number',
#   'part',
#   'idea',
#   'extension',
#   'opposition',
#   'philosophy',
#   'circumstance',
#   'influence',
#   'understanding',
#   'authority',
#   'argument',
#   'time',
#   'sentiment',
#   'interest',
#   'moral',
#   'annihilation',
#   'part',
#   'matter',
#   'deity',
#   'part',
#   'rest',
#   'extent',
#   'relation',
#   'object',
#   'imagination',
#   'cause',
#   'object',
#   'relation',
#   'matter',
#   'fact',
#   'custom',
#   'custom',
#   'effect',
#   'perception',
#   'custom',
#   'reasoning',
#   'perception',
#   'effect',
#   'repetition',
#   'connexion',
#   'operation',
#   'principle',
#   'instinct',
#   'avoid',
#   'evil',
#   'idea',
#   'period',
#   'time',
#   'passion',
#   'disorder',
#   'soul',
#   'determination',
#   'reason',
#   'faculty',
#   'judge',
#   'interest',
#   'dimension',
#   'part',
#   'part',
#   'perception',
#   'extension',
#   'thought',
#   'part',
#   'well',
#   'body',
#   'wonder',
#   'beauty',
#   'object',
#   'pride',
#   'deformity',
#   'humility',
#   'case',
#   'quality',
#   'mind',
#   'cause',
#   'love',
#   'pride',
#   'cause',
#   'man',
#   'way',
#   'living',
#   'birth',
#   'quality',
#   'thing',
#   'industry',
#   'conceal',
#   'pretension',
#   'doubt',
#   'regard',
#   'passion',
#   'sensation',
#   'object',
#   'relation',
#   'relation',
#   'object',
#   'case',
#   'object',
#   'return',
#   'facility',
#   'relation',
#   'object',
#   'relation',
#   'present',
#   'impulse',
#   'imagination',
#   'birth',
#   'quality',
#   'share',
#   'argument',
#   'object',
#   'duty',
#   'time',
#   'dignity',
#   'force',
#   'relation',
#   'call',
#   'occupation',
#   'possession',
#   'property',
#   'object',
#   'cause',
#   'property',
#   'attention',
#   'hypothesis',
#   'partiality',
#   'fault',
#   'discover',
#   'absurdity',
#   'examination',
#   'mistake',
#   'attention',
#   'difficulty',
#   'variety',
#   'fortune',
#   'interest',
#   'concern',
#   'satisfaction',
#   'difference',
#   'judgment',
#   'enquire',
#   'principle',
#   'number',
#   'cause',
#   'influence',
#   'action',
#   'occasion',
#   'denial',
#   'try',
#   'move',
#   'way',
#   'image',
#   'side',
#   'mind',
#   'body',
#   'degree',
#   'force',
#   'activity',
#   'action',
#   'expense',
#   'rest',
#   'sense',
#   'question',
#   'metaphysic',
#   'answer',
#   'life',
#   'idea',
#   'self',
#   'person',
#   'determinate',
#   'idea',
#   'substance',
#   'collection',
#   'quality',
#   'talk',
#   'reason',
#   'eye',
#   'socket',
#   'perception',
#   'principle',
#   'difference',
#   'fitness',
#   'unfitness',
#   'thing',
#   'relation',
#   'immutable',
#   'creature',
#   'effect',
#   'influence',
#   'deity',
#   'specie',
#   'success',
#   'side',
#   'commander',
#   'quality',
#   'courage',
#   'conduct',
#   'courage',
#   'ambition',
#   'benevolence',
#   'robber',
#   'supposition',
#   'object',
#   'lie',
#   'quality',
#   'necessity',
#   'orthodoxy',
#   'belief',
#   'sentiment',
#   'conception',
#   'object',
#   'imagination',
#   'truth',
#   'history',
#   'experience',
#   'system',
#   'moral',
#   'instance',
#   'vice',
#   'merit',
#   'demerit',
#   'source',
#   'case',
#   'reasoning',
#   'supposition',
#   'impression',
#   'belief',
#   'existence',
#   'question',
#   'distance',
#   'time',
#   'veneration',
#   'object',
#   'removal',
#   'space',
#   'objection',
#   'mathematic',
#   'indivisibility',
#   'part',
#   'extension',
#   'sight',
#   ...],
#  ['production',
#   'psychoanalyst',
#   'insufficiency',
#   'capitalism',
#   'action',
#   'monopoly',
#   'time',
#   'capital',
#   'system',
#   'production',
#   'capitalism',
#   'production',
#   'market',
#   'abolition',
#   'privilege',
#   'party',
#   'group',
#   'claim',
#   'speaking',
#   'masse',
#   'pressure',
#   'reproduction',
#   'production',
#   'pressure',
#   'production',
#   'reproduction',
#   'order',
#   'literature',
#   'reality',
#   'question',
#   'rife',
#   'form',
#   'alienation',
#   'child',
#   'estrangement',
#   'family',
#   'relationship',
#   'memory',
#   'alliance',
#   'define',
#   'difference',
#   'separate',
#   'hand',
#   'process',
#   'breakthrough',
#   'accident',
#   'paranoia',
#   'schizophrenia',
#   'pseudo',
#   'etiology',
#   'bear',
#   'field',
#   'name',
#   'history',
#   'name',
#   'precondition',
#   'capitalism',
#   'regime',
#   'slavery',
#   'example',
#   'property',
#   'commodity',
#   'production',
#   'extension',
#   'market',
#   'development',
#   'town',
#   'appearance',
#   'ground',
#   'rent',
#   'money',
#   'form',
#   'hiring',
#   'labor',
#   'economy',
#   'office',
#   'relation',
#   'time',
#   'stage',
#   'slavery',
#   'field',
#   'crossing',
#   'threshold',
#   'individual',
#   'sex',
#   'chain',
#   'intercept',
#   'code',
#   'axiomatic',
#   'block',
#   'seal',
#   'chain',
#   'fact',
#   'energy',
#   'order',
#   'filiation',
#   'distinction',
#   'person',
#   'distinction',
#   'sex',
#   'condition',
#   'capitalism',
#   'objectify',
#   'time',
#   'form',
#   'ownership',
#   'production',
#   'hinge',
#   'way',
#   'structure',
#   'machine',
#   'plane',
#   'consistency',
#   'structuration',
#   'judge',
#   'way',
#   'instance',
#   'power',
#   'aggression',
#   'effect',
#   'effect',
#   'name',
#   'history',
#   'name',
#   'history',
#   'flux',
#   'flood',
#   'sperm',
#   'tyrant',
#   'cradle',
#   'wave',
#   'family',
#   'nature',
#   'class',
#   'apparatus',
#   'use',
#   'benefit',
#   'property',
#   'despotic',
#   'tie',
#   'money',
#   'taxis',
#   'pole',
#   'delirium',
#   'line',
#   'hand',
#   'capitalism',
#   'lack',
#   'aggregate',
#   'lack',
#   'absorption',
#   'overabundant',
#   'resource',
#   'word',
#   'relate',
#   'case',
#   'relationship',
#   'sense',
#   'report',
#   'account',
#   'inscription',
#   'process',
#   'inscription',
#   'numan',
#   'problem',
#   'prestation',
#   'system',
#   'szondi',
#   'situate',
#   'kind',
#   'functioning',
#   'gene',
#   'gene',
#   'example',
#   'relationship',
#   'conflict',
#   'modality',
#   'couch',
#   'force',
#   'outing',
#   'mountain',
#   'voyage',
#   'intensity',
#   'body',
#   'organ',
#   'glory',
#   'denounce',
#   'society',
#   'process',
#   'desire',
#   'man',
#   'alliance',
#   'code',
#   'desire',
#   'debt',
#   'man',
#   'memory',
#   'word',
#   'idea',
#   'man',
#   'therapist',
#   'figure',
#   'breaksflow',
#   'image',
#   'material',
#   'form',
#   'reproduction',
#   'field',
#   'form',
#   'value',
#   'body',
#   'organ',
#   'reproduce',
#   'shoot',
#   'branch',
#   'corner',
#   'point',
#   'machine',
#   'machine',
#   'machine',
#   'schizo',
#   'machine',
#   'part',
#   'piece',
#   'flow',
#   'deduction',
#   'prelevement',
#   'stock',
#   'chain',
#   'detachment',
#   'detachement',
#   'man',
#   'stratum',
#   'cell',
#   'molecule',
#   'chain',
#   'jargon',
#   'body',
#   'organ',
#   'socius',
#   'wilderness',
#   'flow',
#   'end',
#   'world',
#   'respect',
#   'machine',
#   'group',
#   'place',
#   'member',
#   'reproduction',
#   'status',
#   'standpoint',
#   'filiation',
#   'machine',
#   'relation',
#   'alliance',
#   'filiation',
#   'role',
#   'family',
#   'dynasty',
#   'mutation',
#   'indecision',
#   'category',
#   'alliance',
#   'stasis',
#   'excitation',
#   'child',
#   'parent',
#   'conflict',
#   'disturbance',
#   'equilibrium',
#   'function',
#   'desire',
#   'connection',
#   'element',
#   'organ',
#   'body',
#   'entity',
#   'silence',
#   'machine',
#   'oedipus',
#   'gain',
#   'time',
#   'child',
#   'countersecting',
#   'example',
#   'part',
#   'century',
#   'steam',
#   'engine',
#   'textile',
#   'machine',
#   'production',
#   'iron',
#   'process',
#   'line',
#   'womb',
#   'invent',
#   'pessimism',
#   'optimism',
#   'investment',
#   'desire',
#   'cut',
#   'interest',
#   'class',
#   'flow',
#   'segregat',
#   'application',
#   'history',
#   'reanimating',
#   'race',
#   'delirium',
#   'continent',
#   'inseparability',
#   'impasse',
#   'resonance',
#   'family',
#   'function',
#   'shift',
#   'suppress',
#   'castration',
#   'organ',
#   'opposition',
#   'freud',
#   'caste',
#   'class',
#   'order',
#   'caste',
#   'status',
#   'declension',
#   'machine',
#   'line',
#   'schizophrenia',
#   'process',
#   'self',
#   'perpetuation',
#   'process',
#   'exasperation',
#   'production',
#   'schizophrenica',
#   'entity',
#   'painting',
#   'axiomatic',
#   'figure',
#   'style',
#   'essence',
#   'painting',
#   'trinity',
#   'image',
#   'neuroticizing',
#   'painting',
#   'process',
#   'goal',
#   'arrest',
#   'interruption',
#   'continuation',
#   'demand',
#   'manner',
#   'one',
#   'chance',
#   'desire',
#   'form',
#   'prison',
#   'sexuality',
#   'category',
#   'secret',
#   'origin',
#   'lie',
#   'system',
#   'writing',
#   'writing',
#   'surface',
#   'kind',
#   'writing',
#   'system',
#   'writing',
#   'inorganization',
#   'synthesis',
#   'signifier',
#   'writing',
#   'decompose',
#   'chain',
#   'sign',
#   'impel',
#   'pseudo',
#   'territoriality',
#   'product',
#   'substitute',
#   'sign',
#   'sign',
#   'earth',
#   'earth',
#   'state',
#   'ownership',
#   'property',
#   'ownership',
#   'state',
#   'servant',
#   'official',
#   'retort',
#   'right',
#   'laziness',
#   'nonproductivity',
#   'dream',
#   'fantasy',
#   'production',
#   'production',
#   'desire',
#   'organization',
#   'thought',
#   'child',
#   'microcosm',
#   'adult',
#   'place',
#   'use',
#   'synthesis',
#   'opposition',
#   'use',
#   'use',
#   'synthesis',
#   'recording',
#   'alliance',
#   'synthesis',
#   'production',
#   'regime',
#   'people',
#   'connection',
#   'object',
#   'family',
#   'right',
#   'meaning',
#   'process',
#   'use',
#   'term',
#   'consumption',
#   'production',
#   'production',
#   'process',
#   'experience',
#   'death',
#   'death',
#   'feeling',
#   'sex',
#   'race',
#   'zone',
#   'intensity',
#   'body',
#   'organ',
#   'machine',
#   'machine',
#   'code',
#   'field',
#   'course',
#   'desire',
#   'thing',
#   'people',
#   'cop',
#   'priest',
#   'establishment',
#   'revolution',
#   'regime',
#   'production',
#   'satisfie',
#   'interest',
#   'perspective',
#   'havoc',
#   'machme',
#   'machine',
#   'time',
#   'engel',
#   'author',
#   'tracing',
#   'flow',
#   'circulate',
#   'signifier',
#   'work',
#   'machine',
#   'horizon',
#   'relationship',
#   'index',
#   'people',
#   'psychoanalyst',
#   'thing',
#   'necessity',
#   'money',
#   'cure',
#   'question',
#   'bill',
#   'problem',
#   'suffering',
#   'capitalism',
#   'confront',
#   'situation',
#   'experience',
#   'existence',
#   'material',
#   'form',
#   'function',
#   'violence',
#   'power',
#   'nietzsche',
#   'existence',
#   'capitalism',
#   'socialism',
#   'task',
#   'oedipus',
#   'point',
#   'reality',
#   'production',
#   'inorganization',
#   'man',
#   'due',
#   'repulsion',
#   'attraction',
#   'body',
#   'organ',
#   'opposition',
#   'organ',
#   'object',
#   'opposition',
#   'opposition',
#   'regard',
#   'organism',
#   'talent',
#   'author',
#   'psychoanalyst',
#   'question',
#   'life',
#   'child',
#   'undertaking',
#   'pierce',
#   'flow',
#   'opening',
#   'adventure',
#   'production',
#   'psychoanalyst',
#   'man',
#   'culture',
#   'oedipus',
#   'complex',
#   'inasmuch',
#   'formation',
#   'effect',
#   'factor',
#   'inasmuch',
#   'formation',
#   'effect',
#   'factor',
#   'process',
#   'process',
#   'schizophrenia',
#   'arrest',
#   'continuation',
#   'finalization',
#   'discovery',
#   'class',
#   'struggle',
#   'role',
#   'history',
#   'man',
#   'class',
#   'nobility',
#   'feudalism',
#   'difference',
#   'class',
#   'industrialist',
#   'banker',
#   'enzyme',
#   'activity',
#   'relationship',
#   'structure',
#   'reactivity',
#   'time',
#   'wonder',
#   'trace',
#   'time',
#   'family',
#   'essence',
#   'representation',
#   'representation',
#   'resolve',
#   'element',
#   'product',
#   'condensation',
#   'identification',
#   'study',
#   'ideology',
#   'history',
#   'movement',
#   'structure',
#   'group',
#   'politic',
#   'tendency',
#   'point',
#   'self',
#   'application',
#   'folly',
#   'group',
#   'place',
#   'body',
#   'master',
#   'reign',
#   'idol',
#   'machine',
#   'name',
#   'philosophy',
#   'immanence',
#   'criterion',
#   'transcendent',
#   'use',
#   'synthesis',
#   'metaphysic',
#   'object',
#   'show',
#   'respect',
#   'relation',
#   'attraction',
#   'repulsion',
#   'state',
#   'sensation',
#   'emotion',
#   'conversion',
#   'form',
#   'case',
#   'process',
#   'neuroticization',
#   'resist',
#   'block',
#   'side',
#   'end',
#   'escape',
#   'repression',
#   'refuge',
#   'repression',
#   'closing',
#   'body',
#   'organ',
#   'machine',
#   'subject',
#   'mistake',
#   'formation',
#   'isolation',
#   'factor',
#   'coexist',
#   'part',
#   'transcendent',
#   'chain',
#   'form',
#   'reproduce',
#   'limit',
#   'pass',
#   'formation',
#   'suffocate',
#   'mouth',
#   'evidence',
#   'fact',
#   'desire',
#   'object',
#   'person',
#   'thing',
#   'surrounding',
#   'vibration',
#   'sort',
#   'capture',
#   'desire',
#   'gigantism',
#   'machine',
#   'category',
#   'economy',
#   'desire',
#   'body',
#   'organ',
#   'distinction',
#   'agent',
#   'part',
#   'relation',
#   'production',
#   'relation',
#   'order',
#   'fact',
#   'time',
#   'strike',
#   'song',
#   'line',
#   'factory',
#   'condition',
#   'cure',
#   'fact',
#   'crux',
#   'problem',
#   'force',
#   'organmachine',
#   'world',
#   'perspective',
#   'flux',
#   'point',
#   'view',
#   'energy',
#   'eye',
#   'understanding',
#   'term',
#   'disjunction',
#   'connection',
#   'conjunction',
#   'context',
#   'machine',
#   'mechanism',
#   'mechanism',
#   'interest',
#   'myth',
#   'tragedy',
#   'time',
#   'desire',
#   'desire',
#   'man',
#   'strength',
#   'fit',
#   'process',
#   'machine',
#   'manner',
#   'organism',
#   'object',
#   'body',
#   'organ',
#   'synthesis',
#   'disjunction',
#   'conjunction',
#   'permutation',
#   'body',
#   'synthesis',
#   'culture',
#   'producuc',
#   'insert',
#   'reproduction',
#   'father',
#   'schizo',
#   'show',
#   'gap',
#   'drivel',
#   'confusion',
#   'structure',
#   'time',
#   'incest',
#   'form',
#   'person',
#   'repress',
#   'incest',
#   'substance',
#   'earth',
#   'symbol',
#   'meeting',
#   'place',
#   'church',
#   'life',
#   'concept',
#   'production',
#   'insertion',
#   'desire',
#   'infrastructure',
#   'insertion',
#   'symbol',
#   'machine',
#   'function',
#   'machine',
#   'machine',
#   'function',
#   'machine',
#   'investment',
#   'machine',
#   'desire',
#   'level',
#   'metaphor',
#   'notion',
#   'foreclosure',
#   'example',
#   'deficiency',
#   'course',
#   'axi',
#   'orbit',
#   'perspective',
#   'example',
#   'generation',
#   'mother',
#   'desire',
#   'mother',
#   'fade',
#   'break',
#   'cleavage',
#   'castration',
#   'flow',
#   'iron',
#   'opening',
#   'side',
#   'formation',
#   'limit',
#   'find',
#   'sense',
#   'image',
#   'flow',
#   'image',
#   'desire',
#   'people',
#   'one',
#   'reform',
#   'ethnologist',
#   'compel',
#   'psychoanalyst',
#   'part',
#   'discovery',
#   'material',
#   'interpretation',
#   'synthesis',
#   'assignment',
#   'signifier',
#   'determination',
#   'signified',
#   'time',
#   'ageless',
#   'future',
#   'datum',
#   'information',
#   'transmission',
#   'form',
#   'grid',
#   'disjunction',
#   'type',
#   'differ',
#   'connection',
#   'idea',
#   'conscience',
#   'transformation',
#   'place',
#   'term',
#   'share',
#   'affinity',
#   'caste',
#   'outcaste',
#   'nor',
#   'desire',
#   'desire',
#   'today',
#   'wage',
#   'earner',
#   'class',
#   'union',
#   'debt',
#   'alliance',
#   'filiation',
#   'order',
#   'form',
#   'extension',
#   'representation',
#   'repression',
#   'intensity',
#   'experience',
#   'member',
#   'human',
#   'specie',
#   'nature',
#   'nature',
#   'process',
#   'production',
#   'machine',
#   'man',
#   'abet',
#   'incest',
#   'operation',
#   'end',
#   'chain',
#   'territory',
#   'debt',
#   'alliance',
#   'filiation',
#   'filiation',
#   'peregrination',
#   'way',
#   'earth',
#   'moment',
#   'dimension',
#   'representation',
#   'surface',
#   'organization',
#   'voice',
#   'organization',
#   'representing',
#   'instance',
#   'repressing',
#   'representation',
#   'prohibition',
#   'incest',
#   'representation',
#   'repression',
#   'representation',
#   'return',
#   'relationship',
#   'schizophrenia',
# ...
#   'birth',
#   'control',
#   'invent',
#   'charge',
#   'suit',
#   'slaveowner',
#   'system',
#   'slave',
#   'term',
#   'rate',
#   'productivity',
#   'relf',
#   'document',
#   'content',
#   'request',
#   'room',
#   'support',
#   'lady',
#   'question',
#   'principle',
#   'expediency',
#   'feeling',
#   'southerner',
#   'opportunity',
#   'standard',
#   'role',
#   'wife',
#   'mother',
#   'slave',
#   'woman',
#   'breeder',
#   'infant',
#   'child',
#   'calf',
#   'league',
#   'woman',
#   'group',
#   'history',
#   'woman',
#   'education',
#   'woman',
#   'war',
#   'battle',
#   'illiteracy',
#   'work',
#   'task',
#   'land',
#   'power',
#   'point',
#   'man',
#   'rapist',
#   'slavery',
#   'slaveocracy',
#   'tyrant',
#   'address',
#   'soldier',
#   'consciousness',
#   'contemporary',
#   'man',
#   'woman',
#   'communist',
#   'kinship',
#   'struggle',
#   'rape',
#   'victim',
#   'sympathy',
#   'man',
#   'uniform',
#   'robe',
#   'profit',
#   'food',
#   'chain',
#   'bear',
#   'witness',
#   'fact',
#   'woman',
#   'work',
#   'meal',
#   'school',
#   'teacher',
#   'terrell',
#   'woman',
#   'woman',
#   'situation',
#   'job',
#   'boot',
#   'show',
#   'sign',
#   'woman',
#   'worker',
#   'percent',
#   'service',
#   'occupation',
#   'rape',
#   'fact',
#   'expression',
#   'control',
#   'woman',
#   'worker',
#   'wave',
#   'lynching',
#   'abuse',
#   'woman',
#   'woman',
#   'club',
#   'rapist',
#   'justice',
#   'rape',
#   'charge',
#   'man',
#   'juncture',
#   'rape',
#   'justification',
#   'woman',
#   'rape',
#   'movement',
#   'rape',
#   'weapon',
#   'educator',
#   'post',
#   'war',
#   'period',
#   'campaign',
#   'spokeswoman',
#   'advocate',
#   'imprisonment',
#   'woman',
#   'environment',
#   'home',
#   'woman',
#   'right',
#   'year',
#   'woman',
#   'movement',
#   'ability',
#   'isolation',
#   'home',
#   'people',
#   'earning',
#   'ancestor',
#   'read',
#   'crandall',
#   'pupil',
#   'jail',
#   'convention',
#   'freedman',
#   'resolution',
#   'equality',
#   'woman',
#   'country',
#   'rape',
#   'law',
#   'protection',
#   'man',
#   'class',
#   'daughter',
#   'wife',
#   'pattern',
#   'capitulation',
#   'racism',
#   'juncture',
#   'expansion',
#   'form',
#   'racism',
#   'well',
#   'woman',
#   'defeat',
#   'resolution',
#   'people',
#   'insult',
#   'assault',
#   'reminder',
#   'boy',
#   'mind',
#   'bed',
#   'ashtray',
#   'cup',
#   'extent',
#   'cause',
#   'sex',
#   'attention',
#   'woman',
#   'adversary',
#   'truth',
#   'hero',
#   'emancipation',
#   'hour',
#   'hour',
#   'working',
#   'condition',
#   'living',
#   'quarter',
#   'time',
#   'meal',
#   'hour',
#   'noon',
#   'dinner',
#   'woman',
#   'weaving',
#   'room',
#   'block',
#   'house',
#   'meal',
#   'day',
#   'terror',
#   'woman',
#   'convention',
#   'woman',
#   'right',
#   'slavery',
#   'time',
#   'man',
#   'treatment',
#   'wife',
#   'effort',
#   'movement',
#   'race',
#   'feminism',
#   'aspiration',
#   'woman',
#   'society',
#   'woman',
#   'assault',
#   'system',
#   'war',
#   'number',
#   'woman',
#   'industry',
#   'comment',
#   'ease',
#   'prudence',
#   'crandall',
#   'girl',
#   'woman',
#   ...],
#  ['substance',
#   'face',
#   'expression',
#   'resonance',
#   'levina',
#   'other',
#   'tear',
#   'literality',
#   'metaphor',
#   'matter',
#   'height',
#   'height',
#   'image',
#   'sleep',
#   'consciousness',
#   'point',
#   'sense',
#   'universality',
#   'eye',
#   'truth',
#   'night',
#   'opposition',
#   'servility',
#   'stock',
#   'lordship',
#   'concern',
#   'norm',
#   'intention',
#   'place',
#   'level',
#   'knowledge',
#   'anguish',
#   'anguish',
#   'characteristic',
#   'origin',
#   'historicity',
#   'traditionality',
#   'telo',
#   'history',
#   'philosophy',
#   'witness',
#   'dialogue',
#   'set',
#   'set',
#   'party',
#   'transparency',
#   'meaning',
#   'finitude',
#   'appearance',
#   'question',
#   'question',
#   'irreducible',
#   'form',
#   'experience',
#   'egoity',
#   'error',
#   'artaud',
#   'history',
#   'trace',
#   'way',
#   'truth',
#   'dream',
#   'form',
#   'writing',
#   'kind',
#   'transposition',
#   'dream',
#   'condensation',
#   'displacement',
#   'system',
#   'hieroglyphic',
#   'example',
#   'fragility',
#   'tree',
#   'garden',
#   'solitude',
#   'philosophy',
#   'difference',
#   'culmination',
#   'root',
#   'passageway',
#   'book',
#   'line',
#   'writing',
#   'limit',
#   'restoration',
#   'repetition',
#   'meaning',
#   'word',
#   'act',
#   'question',
#   'injunction',
#   'question',
#   'signification',
#   'origin',
#   'question',
#   'stage',
#   'stage',
#   'word',
#   'man',
#   'believe',
#   'moment',
#   'death',
#   'theater',
#   'force',
#   'essence',
#   'essence',
#   'project',
#   'narration',
#   'genitivity',
#   'speech',
#   'cut',
#   'existent',
#   'levina',
#   'terminology',
#   'way',
#   'conceptualize',
#   'encounter',
#   'category',
#   'sense',
#   'movement',
#   'signification',
#   'result',
#   'fact',
#   'addition',
#   'function',
#   'lack',
#   'part',
#   'value',
#   'value',
#   'value',
#   'time',
#   'part',
#   'object',
#   'perception',
#   'image',
#   'telescope',
#   'passage',
#   'light',
#   'ray',
#   'origin',
#   'work',
#   'structure',
#   'unity',
#   'structuralist',
#   'criticism',
#   'thing',
#   'attention',
#   'historicity',
#   'arrival',
#   'philosophy',
#   'determination',
#   'presence',
#   'space',
#   'opening',
#   'other',
#   'time',
#   'limit',
#   'violence',
#   'nonviolence',
#   'speech',
#   'writing',
#   'concept',
#   'representation',
#   'language',
#   'possibility',
#   'face',
#   'face',
#   'inferiority',
#   'humility',
#   'glance',
#   'child',
#   'memory',
#   'walk',
#   'infan',
#   'hand',
#   'master',
#   'seab',
#   'anxiety',
#   'life',
#   'curve',
#   'form',
#   'reason',
#   'dun',
#   'presence',
#   'level',
#   'metaphysic',
#   'theology',
#   'violence',
#   'relationship',
#   'being',
#   'face',
#   'violence',
#   'nonviolence',
#   'center',
#   'work',
#   'answer',
#   'determine',
#   'fish',
#   'water',
#   'consonant',
#   'scale',
#   'time',
#   'difference',
#   'production',
#   'trace',
#   'moment',
#   'production',
#   'destruction',
#   'value',
#   'energy',
#   'energy',
#   'aim',
#   'escape',
#   'phenomenology',
#   'economy',
#   'contradiction',
#   'term',
#   'logic',
#   'levina',
#   'refuse',
#   'alter',
#   'ego',
#   'impossibility',
#   'relation',
#   'coherence',
#   'language',
#   'contradiction',
#   'impossibility',
#   'sign',
#   'irrationality',
#   'sign',
#   'inspiration',
#   'coherence',
#   'region',
#   'language',
#   'total',
#   'derangement',
#   'time',
#   'rhythm',
#   'alternation',
#   'writing',
#   'illiterate',
#   'civilization',
#   'artaud',
#   'illiteracy',
#   'living',
#   'culture',
#   'alienation',
#   'insistence',
#   'heaviness',
#   'spectator',
#   'director',
#   'actor',
#   'force',
#   'space',
#   'stage',
#   'regard',
#   'age',
#   'specificity',
#   'privilege',
#   'mourn',
#   'center',
#   'signify',
#   'twisting',
#   'letter',
#   'letter',
#   'irreality',
#   'meaning',
#   'phenomenology',
#   'syntax',
#   'series',
#   'event',
#   'body',
#   'rule',
#   'production',
#   'independence',
#   'self',
#   'consciousness',
#   'moment',
#   'liberate',
#   'start',
#   'work',
#   'dialectic',
#   'recherche',
#   'perceive',
#   'episode',
#   'levinas',
#   'fact',
#   'modification',
#   'act',
#   'deprive',
#   'foundation',
#   'possibility',
#   'language',
#   'theft',
#   'possession',
#   'theft',
#   'thing',
#   'possession',
#   'meaning',
#   'value',
#   'consecration',
#   'vow',
#   'return',
#   'point',
#   'retake',
#   'possession',
#   'form',
#   'book',
#   'model',
#   'meaning',
#   'system',
#   'norm',
#   'society',
#   'structure',
#   'culture',
#   'economy',
#   'violence',
#   'ground',
#   'reason',
#   'gesture',
#   'artaud',
#   'body',
#   'language',
#   'member',
#   'word',
#   'consciousness',
#   'act',
#   'life',
#   'blood',
#   'color',
#   'nuance',
#   'life',
#   'death',
#   'reduction',
#   'reduction',
#   'essentialist',
#   'text',
#   'superstructure',
#   'idealization',
#   'value',
#   'exactitude',
#   'sedimentation',
#   'layer',
#   'truth',
#   'discontinuity',
#   'hypothesis',
#   'clarification',
#   'insistence',
#   'period',
#   'case',
#   'interval',
#   'discontinuity',
#   'support',
#   'art',
#   'literature',
#   'example',
#   'literature',
#   'affirmation',
#   'sake',
#   'movement',
#   'count',
#   'earth',
#   'colour',
#   'figure',
#   'thing',
#   'genius',
#   'order',
#   'trap',
#   'credulity',
#   'hand',
#   'eye',
#   'flesh',
#   'blood',
#   'sense',
#   'meditiation',
#   'reason',
#   'necessity',
#   'price',
#   'war',
#   'language',
#   'reason',
#   'war',
#   'language',
#   'act',
#   'destruction',
#   'allegation',
#   'silence',
#   'virtue',
#   'word',
#   'unity',
#   'word',
#   'concept',
#   'specification',
#   'ascendancy',
#   'measure',
#   'impotency',
#   'fear',
#   'stage',
#   'find',
#   'body',
#   'history',
#   'field',
#   'work',
#   'work',
#   'way',
#   'discovery',
#   'speculation',
#   'sign',
#   'transcribe',
#   'speech',
#   'master',
#   'self',
#   'truth',
#   'passion',
#   'faith',
#   'duty',
#   'etc',
#   'truth',
#   'biography',
#   'psychology',
#   'interest',
#   'movement',
#   'specificity',
#   'none',
#   'movement',
#   'writing',
#   'experience',
#   'divinity',
#   'deity',
#   'toe',
#   'book',
#   'sense',
#   'wod',
#   'person',
#   'author',
#   'madness',
#   'self',
#   'consciousness',
#   'interpretation',
#   'mallarme',
#   'sow',
#   'volume',
#   'time',
#   'category',
#   'category',
#   'hole',
#   'detour',
#   'labyrinth',
#   'function',
#   'concept',
#   'experience',
#   'metaphysic',
#   'presence',
#   'silence',
#   'letter',
#   'importance',
#   'speech',
#   'undoing',
#   'telo',
#   'relationship',
#   'relationship',
#   'respect',
#   'question',
#   'negation',
#   'time',
#   'cessation',
#   'time',
#   'simultaneity',
#   'structure',
#   'stratification',
#   'time',
#   'consciousness',
#   'scrutiny',
#   'operation',
#   'history',
#   'route',
#   'thought',
#   'question',
#   'dialogue',
#   'discourse',
#   'vantage',
#   'point',
#   'way',
#   'finalism',
#   'effort',
#   'movement',
#   'necessity',
#   'necessity',
#   'conceptuality',
#   'order',
#   'destroy',
#   'context',
#   'passage',
#   'allusion',
#   'letter',
#   'text',
#   'intentionality',
#   'knowledge',
#   'idea',
#   'infinity',
#   'adequation',
#   'excellence',
#   'regard',
#   'recognizing',
#   'thing',
#   'facade',
#   'theorem',
#   'place',
#   'difference',
#   'proceeding',
#   'crime',
#   'work',
#   'hundred',
#   'text',
#   'scene',
#   'history',
#   'relation',
#   'thought',
#   'comte',
#   'cloud',
#   'professor',
#   'village',
#   'wedding',
#   'philosophy',
#   'question',
#   'question',
#   'end',
#   'life',
#   'problem',
#   'course',
#   'card',
#   'phenomenology',
#   'mind',
#   'impression',
#   'completion',
#   'sense',
#   'infinity',
#   'operation',
#   'difference',
#   'determination',
#   'thinking',
#   'negativity',
#   'negativity',
#   'difference',
#   'life',
#   'death',
#   'one',
#   'crime',
#   'dream',
#   'thought',
#   'source',
#   'writing',
#   'unity',
#   'concept',
#   'concept',
#   'characteristic',
#   'form',
#   'predicate',
#   'difference',
#   'height',
#   'form',
#   'eternity',
#   'language',
#   'history',
#   'madness',
#   'effect',
#   'necessity',
#   'discourse',
#   'call',
#   'relativity',
#   'recourse',
#   'support',
#   'reason',
#   'history',
#   'state',
#   'knowledge',
#   'sand',
#   'man',
#   'war',
#   'war',
#   'war',
#   'discourse',
#   'violence',
#   'recapitulation',
#   'text',
#   'trace',
#   'memory',
#   'work',
#   'trace',
#   'route',
#   'trace',
#   'trace',
#   'break',
#   'path',
#   'difference',
#   'sense',
#   'moment',
#   'analysis',
#   'reference',
#   'idea',
#   'sense',
#   'irruption',
#   'consciousness',
#   'unification',
#   'flux',
#   'consciousness',
#   'unifie',
#   'world',
#   'anticipation',
#   'incompleteness',
#   'structure',
#   'way',
#   'appresentation',
#   'communion',
#   'experience',
#   'appearance',
#   'transposition',
#   'disease',
#   'impossibility',
#   'dance',
#   'theater',
#   'consideran',
#   'moment',
#   'moment',
#   'movement',
#   'experience',
#   'discreet',
#   'movement',
#   'triumphant',
#   'stupidity',
#   'view',
#   'laughter',
#   'anguish',
#   'laughter',
#   'fear',
#   'image',
#   'relation',
#   'speech',
#   'language',
#   'aid',
#   'submission',
#   'necessity',
#   'specificity',
#   'beauty',
#   'gain',
#   'effort',
#   'silence',
#   'archaeology',
#   'muteness',
#   'nondiscourse',
#   'silence',
#   'dis',
#   'course',
#   'command',
#   'issue',
#   'origin',
#   'protectionism',
#   'reason',
#   'barrier',
#   'madness',
#   'barrier',
#   'madness',
#   'origin',
#   'logo',
#   'trade',
#   'logo',
#   'reason',
#   'madness',
#   'logo',
#   'dialogue',
#   'reason',
#   'circulation',
#   'rousset',
#   'contradiction',
#   'book',
#   'question',
#   'page',
#   'text',
#   'analogy',
#   'writing',
#   'apparatus',
#   'apparatus',
#   'step',
#   'possibility',
#   'limit',
#   'contact',
#   'paper',
#   'wax',
#   'slab',
#   'place',
#   'visibility',
#   'writing',
#   'end',
#   'recur',
#   'surface',
#   'power',
#   'attempt',
#   'theater',
#   'authority',
#   'text',
#   'text',
#   'diffuse',
#   'boring',
#   'esthetic',
#   'stage',
#   'diction',
#   'levina',
#   'logic',
#   'ethic',
#   'world',
#   'mouth',
#   'imprint',
#   'skin',
#   'book',
#   'book',
#   'understanding',
#   'explication',
#   'objectification',
#   'route',
#   'science',
#   'mind',
#   'layer',
#   'end',
#   'distinction',
#   'discourse',
#   'horizon',
#   'perforation',
#   'operation',
#   'condition',
#   'meaning',
#   'point',
#   'departure',
#   'andifil',
#   'nonbasis',
#   'play',
#   'discourse',
#   'history',
#   'meaning',
#   'explication',
#   'phenomenon',
#   'force',
#   'tautology',
#   'crisis',
#   'levina',
#   'substance',
#   'example',
#   'principe',
#   'notion',
#   'structure',
#   'genesis',
#   'dissociation',
#   'reduction',
#   'interrogate',
#   'reduction',
#   'homage',
#   'idea',
#   'principle',
#   'reliving',
#   'nachleben',
#   'notion',
#   'notion',
#   'intention',
#   'mind',
#   'production',
#   'meaning',
#   'question',
#   'possibility',
#   'science',
#   'mind',
#   'idea',
#   'structure',
#   'unity',
#   'organism',
#   'world',
#   'function',
#   'manifestation',
#   'correspond',
#   'distinction',
#   'structure',
#   'principle',
#   'relationship',
#   'causality',
#   'structure',
#   'principle',
#   'relationship',
#   'motivation',
#   'case',
#   'war',
#   'asymmetry',
#   'collaborate',
#   'meaning',
#   'expenditure',
#   'negativity',
#   'reserve',
#   'negativity',
#   'process',
#   'system',
#   'depth',
#   'one',
#   'risk',
#   'work',
#   'writing',
#   'alter',
#   'ego',
#   'speech',
#   'theater',
#   'cruelty',
#   'stage',
#   'dictionary',
#   'specie',
#   'noun',
#   'noun',
#   'category',
#   'essay',
#   'claudel',
#   'essay',
#   'structure',
#   'rousset',
#   'accident',
#   'episode',
#   'character',
#   'independence',
#   'theme',
#   'work',
#   'lie',
#   'confrontation',
#   'proust',
#   'novelist',
#   'proust',
#   'rousset',
#   'truth',
#   'love',
#   'analogy',
#   'dialogue',
#   'hand',
#   'instrument',
#   'disposition',
#   'eye',
#   'operation',
#   'trial',
#   'error',
#   'adapt',
#   'hesitating',
#   'change',
#   'try',
#   'form',
#   'theft',
#   'body',
#   'body',
#   'thing',
#   'deconstitution',
#   'diaphanousness',
#   'flesh',
#   'word',
#   'word',
#   'intensity',
#   'shout',
#   'articulation',
#   'language',
#   'logic',
#   'aspect',
#   'gesture',
#   'speech',
#   'movement',
#   'generality',
#   'repetition',
#   'structure',
#   'order',
#   'oppose',
#   'series',
#   'system',
#   'privilege',
#   'series',
#   'structuralism',
#   'spot',
#   'hegelianism',
#   'representation',
#   'meaning',
#   'point',
#   'destruction',
#   'suppression',
#   'death',
#   'sacrifice',
#   'expenditure',
#   'negativity',
#   'irregionality',
#   'noema',
#   'determination',
#   'totality',
#   'region',
#   'stricto',
#   'sensu',
#   'basis',
#   'structure',
#   'descarte',
#   'reader',
#   'interlocutor',
#   'pretend',
#   'account',
#   'write',
#   'hand',
#   'body',
#   'mine',
#   'person',
#   'sense',
#   'theater',
#   'word',
#   'man',
#   'metaphor',
#   'state',
#   'affair',
#   'grouping',
#   'energy',
#   'structure',
#   'question',
#   'agency',
#   'companionship',
#   'form',
#   'face',
#   'face',
#   'encounter',
#   'face',
#   'point',
#   'view',
#   'point',
#   'descarte',
#   'question',
#   'today',
#   'founding',
#   'community',
#   'world',
#   'philosopher',
#   'remembrance',
#   'fact',
#   'question',
#   'language',
#   'publication',
#   'technique',
#   'moment',
#   'madness',
#   'madness',
#   'language',
#   'chain',
#   'reason',
#   'question',
#   'signification',
#   'term',
#   'reason',
#   'complicity',
#   'world',
#   'place',
#   'speech',
#   'prescription',
#   'cruelty',
#   'text',
#   'zone',
#   'sovereignty',
#   'philosophy',
#   'heidegger',
#   'metaphysic',
#   'primacy',
#   'object',
#   'objectivity',
#   'infinity',
#   'form',
#   'infinity',
#   'project',
#   'dissension',
#   'project',
#   'archaeology',
#   'silence',
#   'question',
#   'question',
#   'method',
#   'present',
#   'chance',
#   'technique',
#   'miteinandersein',
#   'collectivity',
#   'form',
#   'truth',
#   'question',
#   'answer',
#   'delay',
#   'stage',
#   'representation',
#   'liberate',
#   'play',
#   'signifier',
#   'place',
#   'moment',
#   'elusion',
#   'man',
#   'totality',
#   'history',
#   'event',
#   'principle',
#   'concept',
#   ...]]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_processed) # converts each word into an integer value (sort of like an ID)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_processed]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                       id2word=id2word,
                                       num_topics= 5, 
                                       random_state=100,
                                       chunksize=10,
                                       passes=10,
                                       iterations=100,
                                       per_word_topics=True, 
                                       minimum_probability=0.0)

# %%
## MODEL PERFORMANCE

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, 
                                     texts=data_processed, 
                                     dictionary=id2word, 
                                     coherence='c_v')

coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.296653918795195
#
# Coherence Score:  0.47727835004658914

# %%
# Inspect contents of the model (save as csv?)
pprint(lda_model.print_topics())
topic_df = pd.DataFrame(lda_model.print_topics())
# Out:
# [(0,
#   '0.017*"country" + 0.017*"part" + 0.016*"price" + 0.014*"value" + '
#   '0.013*"labour" + 0.011*"capital" + 0.011*"money" + 0.010*"trade" + '
#   '0.010*"quantity" + 0.010*"land"'),
#  (1,
#   '0.025*"thing" + 0.022*"idea" + 0.019*"reason" + 0.018*"object" + '
#   '0.015*"body" + 0.015*"mind" + 0.014*"nature" + 0.012*"man" + 0.012*"sense" '
#   '+ 0.011*"part"'),
#  (2,
#   '0.021*"world" + 0.011*"language" + 0.011*"time" + 0.010*"form" + '
#   '0.009*"way" + 0.009*"fact" + 0.009*"case" + 0.008*"question" + 0.008*"word" '
#   '+ 0.008*"theory"'),
#  (3,
#   '0.032*"man" + 0.022*"woman" + 0.022*"thing" + 0.010*"people" + 0.009*"life" '
#   '+ 0.008*"time" + 0.008*"body" + 0.008*"way" + 0.008*"child" + 0.007*"part"'),
#  (4,
#   '0.038*"self" + 0.029*"consciousness" + 0.025*"concept" + '
#   '0.021*"determination" + 0.016*"unity" + 0.015*"moment" + 0.014*"form" + '
#   '0.013*"content" + 0.012*"existence" + 0.012*"law"')]
#    0                                                  1
# 0  0  0.017*"country" + 0.017*"part" + 0.016*"price"...
# 1  1  0.025*"thing" + 0.022*"idea" + 0.019*"reason" ...
# 2  2  0.021*"world" + 0.011*"language" + 0.011*"time...
# 3  3  0.032*"man" + 0.022*"woman" + 0.022*"thing" + ...
# 4  4  0.038*"self" + 0.029*"consciousness" + 0.025*"...

# %%
# Creating a new DF, which assigns which topic is the most dominant, amongst all entries in the corpus
df_topic_keywords = lda_utils.format_topics_sentences(ldamodel=lda_model, 
                                                      corpus=corpus, 
                                                      texts=data_processed)

# titles, authors, schools, and year
df_topic_keywords["Title"] = list(DATA["title"])
df_topic_keywords["Author"] = list(DATA["author"])
df_topic_keywords["School"] = list(DATA["school"])
df_topic_keywords["Year"] = list(DATA["original_publication_date"])

# Format
df_topic_keywords.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text", "Title", "Author", "School", "Year"]

# Quick overview
df_topic_keywords[:5]
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.7117
# 1        1.0              0.9658
# 2        1.0              0.8937
# 3        2.0              0.6970
# 4        3.0              0.7315
#
#                                             Keywords  \
# 0  country, part, price, value, labour, capital, ...
# 1  thing, idea, reason, object, body, mind, natur...
# 2  thing, idea, reason, object, body, mind, natur...
# 3  world, language, time, form, way, fact, case, ...
# 4  man, woman, thing, people, life, time, body, w...
#
#                                  Representative Text  \
# 0  [scale, writing, opinion, regard, difficulty, ...
# 1  [foregoing, principle, scheme, idea, place, th...
# 2  [examination, impression, clearness, idea, exa...
# 3  [production, psychoanalyst, insufficiency, cap...
# 4  [animal, lung, refrigeration, scope, deviation...
#
#                         Title       Author       School  Year
# 0  The Problems Of Philosophy      Russell     analytic  1912
# 1      The Search After Truth  Malebranche  rationalism  1674
# 2      Thus Spake Zarathustra    Nietzsche    nietzsche  1887
# 3      Plato - Complete Works        Plato        plato  -350
# 4                Quintessence        Quine     analytic  1950

# %%
# Get the probability of each topic for eery document
values = list(lda_model.get_document_topics(corpus))

# %%
# Split topics and keep only values per topic
split = []
for entry in values:
    topic_prevelance = []
    for topic in entry:
        topic_prevelance.append(topic[1])
    split.append(topic_prevelance)

# %%
# Save as df and combine with the topic keyword df
split = pd.DataFrame(split, columns=["Topic1", "Topic2", "Topic3", "Topic4", "Topic5"])

# %%
df_topic_keywords = pd.concat([df_topic_keywords, split], axis=1)

# %%
df_topic_keywords[:3]
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.7117
# 1        1.0              0.9658
# 2        1.0              0.8937
#
#                                             Keywords  \
# 0  country, part, price, value, labour, capital, ...
# 1  thing, idea, reason, object, body, mind, natur...
# 2  thing, idea, reason, object, body, mind, natur...
#
#                                  Representative Text  \
# 0  [scale, writing, opinion, regard, difficulty, ...
# 1  [foregoing, principle, scheme, idea, place, th...
# 2  [examination, impression, clearness, idea, exa...
#
#                         Title       Author       School  Year    Topic1  \
# 0  The Problems Of Philosophy      Russell     analytic  1912  0.711661
# 1      The Search After Truth  Malebranche  rationalism  1674  0.000246
# 2      Thus Spake Zarathustra    Nietzsche    nietzsche  1887  0.023589
#
#      Topic2    Topic3    Topic4    Topic5
# 0  0.062741  0.214356  0.000061  0.011181
# 1  0.965814  0.000243  0.033457  0.000241
# 2  0.893678  0.000033  0.082667  0.000033

# %% [markdown]
# __PCA feature reduction__

# %%
# Reduce feature space 
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df_topic_keywords.set_index("Year").iloc[:,8:])
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['Principal Component 1', 'Principal Component 2'])

# Adding Year
principalDf["Year"] = df_topic_keywords["Year"]

# %%
# I plot the PCA component scores of each document to see potential clusters spatially. Colored by year.
plot_texts_pda = sns.relplot(
    data=principalDf,
    x="principal component 1", y="principal component 2", hue = "Year").fig.suptitle("2 Component Topic Model Space")

plot_texts_pda

# Saving to out
fig = plot_texts_pda.get_figure()
fig.savefig(os.path.join("out", "PCA_plot.png"))
